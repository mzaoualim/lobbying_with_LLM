# %% [markdown]
# <a href="https://colab.research.google.com/github/mzaoualim/lobbying_with_LLM/blob/main/steps_lobby_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#Steps
## twitter data
## LLM analysis
## testing again major policy

# %% [markdown]
# # Getting X (twitter) data

# %% [markdown]
# Making a starter dataframe with:
#   * US congress representatives list
#   * coupled with their official X (twitter) account.

# %%
# account list
raw_list = pd.read_html('https://pressgallery.house.gov/member-data/members-official-twitter-handles', skiprows=[0,1], header=0)[0]

# %%
raw_list
# Out:
#     FirstName  LastName    Twitter Handle St/Dis Party
# 0        Alma     Adams         @RepAdams   NC12     D
# 1      Robert  Aderholt  @Robert_Aderholt   AL04     R
# 2        Pete   Aguilar   @RepPeteAguilar   CA31     D
# 3        Mark    Alford    @RepMarkAlford   MO04     R
# 4        Rick     Allen     @RepRickAllen   GA12     R
# ..        ...       ...               ...    ...   ...
# 433       Joe    Wilson     @RepJoeWilson   SC02     R
# 434    Robert   Wittman       @RobWittman   VA01     R
# 435     Steve    Womack  @rep_stevewomack   AR03     R
# 436      Rudy     Yakym     @RepRudyYakym   IN02     R
# 437      Ryan     Zinke     @RepRyanZinke   MT01     R
#
# [438 rows x 5 columns]
